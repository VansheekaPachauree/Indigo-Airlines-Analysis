# %%
import pandas as pd
import numpy as np
from sklearn.linear_model import LinearRegression
import statsmodels.api as sm
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn import preprocessing
from scipy import stats
from scipy.special import boxcox1p
from mpl_toolkits.mplot3d import Axes3D

# %%
Swot = pd.read_excel('EXCELforSWOTChangedN.xlsx')
Swot
# Out:
#      On_time  Fares  Entertainment  Food  Market_segments  Partner_agencies  \
# 0          4      4              4     4                5                 4
# 1          4      4              4     3                5                 4
# 2          4      4              3     4                3                 4
# 3          4      4              4     4                4                 2
# 4          4      3              4     4                4                 4
# ..       ...    ...            ...   ...              ...               ...
# 118        4      4              3     4                5                 5
# 119        4      4              4     4                3                 3
# 120        4      4              3     3                4                 4
# 121        4      4              3     4                4                 4
# 122        4      2              4     3                1                 4
#
#      Eco_down  Safety  Overall
# 0           2       3        5
# 1           4       4        4
# 2           4       4        4
# 3           5       5        4
# 4           4       4        4
# ..        ...     ...      ...
# 118         4       4        4
# 119         2       4        4
# 120         4       4        4
# 121         4       4        4
# 122         4       2        3
#
# [123 rows x 9 columns]

# %%
#mean
Swot.mean()
# Out:
# On_time             3.886179
# Fares               3.455285
# Entertainment       3.512195
# Food                3.447154
# Market_segments     3.699187
# Partner_agencies    4.000000
# Eco_down            3.878049
# Safety              4.073171
# Overall             3.934959
# dtype: float64

# %%
#Standard deviation
Swot.std()
# Out:
# On_time             0.667799
# Fares               0.791885
# Entertainment       0.852824
# Food                0.888942
# Market_segments     1.023774
# Partner_agencies    0.858898
# Eco_down            0.752976
# Safety              0.801338
# Overall             0.649588
# dtype: float64

# %%
#Skewness
Swot.skew()
# Out:
# On_time            -0.538327
# Fares              -0.807104
# Entertainment      -0.320672
# Food               -0.086861
# Market_segments    -0.902748
# Partner_agencies   -0.710117
# Eco_down           -0.497112
# Safety             -0.813590
# Overall            -0.119201
# dtype: float64
