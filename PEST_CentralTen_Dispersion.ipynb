# %%
import pandas as pd
import numpy as np
from sklearn.linear_model import LinearRegression
import statsmodels.api as sm
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn import preprocessing
from scipy import stats
from scipy.special import boxcox1p
from mpl_toolkits.mplot3d import Axes3D

# %%
Pest = pd.read_excel('PESTEXCEL.xlsx')
Pest
# Out:
#      AIAccess  RAAccess  PsRsChoose  ESAfford  FVTBenefit  GMCBenefit  \
# 0           5         5           5         5           5           5
# 1           4         4           4         4           4           4
# 2           4         4           2         1           5           5
# 3           3         3           2         2           4           3
# 4           4         5           4         5           5           5
# ..        ...       ...         ...       ...         ...         ...
# 123         4         4           4         4           4           4
# 124         3         3           2         3           3           4
# 125         3         3           4         4           4           4
# 126         2         2           2         2           4           4
# 127         4         3           2         3           4           4
#
#      AOConvinient  CSExcellent
# 0               5            5
# 1               4            4
# 2               2            4
# 3               4            3
# 4               4            4
# ..            ...          ...
# 123             4            4
# 124             4            4
# 125             4            2
# 126             4            4
# 127             4            4
#
# [128 rows x 8 columns]

# %%
#MEAN
Pest.mean()
#Pest['AIAccess'].mean(), to calculate the mean of a single column.
# Out:
# AIAccess        3.609375
# RAAccess        3.453125
# PsRsChoose      3.398438
# ESAfford        3.625000
# FVTBenefit      3.937500
# GMCBenefit      3.789062
# AOConvinient    3.898438
# CSExcellent     3.453125
# dtype: float64

# %%
#MEDIAN
Pest.median()
# Out:
# AIAccess        4.0
# RAAccess        4.0
# PsRsChoose      3.5
# ESAfford        4.0
# FVTBenefit      4.0
# GMCBenefit      4.0
# AOConvinient    4.0
# CSExcellent     4.0
# dtype: float64

# %%
#MODE
Pest.mode()
# Out:
#    AIAccess  RAAccess  PsRsChoose  ESAfford  FVTBenefit  GMCBenefit  \
# 0         4         4           4         4           4           4
#
#    AOConvinient  CSExcellent
# 0             4            4

# %%
#Lower Quartile
Pest.quantile([0.25])
# Out:
#       AIAccess  RAAccess  PsRsChoose  ESAfford  FVTBenefit  GMCBenefit  \
# 0.25       3.0       3.0         3.0       3.0         4.0         3.0
#
#       AOConvinient  CSExcellent
# 0.25           4.0          3.0

# %%
#Upper Quartile
Pest.quantile([0.75])
# Out:
#       AIAccess  RAAccess  PsRsChoose  ESAfford  FVTBenefit  GMCBenefit  \
# 0.75       4.0       4.0         4.0       4.0         4.0         4.0
#
#       AOConvinient  CSExcellent
# 0.75           5.0          4.0

# %%
#CALCULATING DISPERSION BELOW

# %%
#STANDARD DEVIATION
Pest.std()
# Out:
# AIAccess        0.805829
# RAAccess        0.868154
# PsRsChoose      0.958508
# ESAfford        0.947437
# FVTBenefit      0.830046
# GMCBenefit      0.961072
# AOConvinient    0.962607
# CSExcellent     1.018408
# dtype: float64

# %%
#COEFF OF SKEWNESS
Pest.skew()
# Out:
# AIAccess       -1.004742
# RAAccess       -0.880516
# PsRsChoose     -0.386635
# ESAfford       -0.818282
# FVTBenefit     -1.476518
# GMCBenefit     -0.861143
# AOConvinient   -1.085205
# CSExcellent    -0.370805
# dtype: float64
